# %% [markdown]
# # Second Classwork – Data Mining (IDM 2025/2026)
#
# In questo secondo classwork l’obiettivo è costruire un **classificatore multi-classe** capace di predire, dato un nuovo paziente, una delle tre classi:
#
# - **ASD**: bambini con diagnosi di autismo
# - **GDD**: bambini con global developmental delay
# - **Controls**: bambini con sviluppo tipico
#
# Il dataset è fornito in formato **Excel** con tre fogli (ASD, GDD, Controls/Controlli). Ogni paziente è descritto da feature discrete con valori in {0, 1, 2}. Prima dell’addestramento va effettuata una pulizia accurata:
#
# - rimuovere le feature **non rilevanti**: `Età cronologica (mesi)`, `Scala B`, `Scala D`, `TOT.`, `Score di rischio`;
# - escludere i pazienti con **Età equivalente < 12 mesi** (per evitare rumore dovuto a feature “defaultate” a 0 nei primi mesi).
#
# Il notebook segue i task richiesti:
#
# 1. **PCA 2D** e scatter plot dei pazienti;
# 2. **Split** train/test;
# 3. Training di più classificatori (Decision Tree, Random Forest, SVC, K-NN) con selezione del migliore tramite **GridSearchCV con 5-fold cross validation**;
# 4. Uso di **bagging** e **boosting** per migliorare le prestazioni.
#
# L’implementazione operativa delle pipeline è incapsulata in moduli `src/phase*.py` basati su TRACCIA; questo notebook si limita ad **orchestrare** le fasi e a visualizzare i risultati.

# %% [markdown]
# ## Setup ambiente
#
# In questa cella installiamo le dipendenze del progetto (incluse `TRACCIA` e le librerie di machine learning).
# Se stai lavorando in un ambiente notebook, potrebbe essere necessario **riavviare il kernel** dopo l’installazione.

# %%
pip install -r requirements.txt # type: ignore
# Out:
# Collecting git+https://github.com/emanuelegaliano/TRACCIA.git (from -r requirements.txt (line 21))
#   Cloning https://github.com/emanuelegaliano/TRACCIA.git to /tmp/pip-req-build-uty20met
#   Running command git clone --filter=blob:none --quiet https://github.com/emanuelegaliano/TRACCIA.git /tmp/pip-req-build-uty20met
#   Resolved https://github.com/emanuelegaliano/TRACCIA.git to commit 4dd9ba02a86286c7e28196f8a24696279416caf0
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas>=1.3.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: matplotlib>=3.4.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (3.9.2)
# Requirement already satisfied: ipython>=7.0.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (8.27.0)
# Requirement already satisfied: jupyter_client>=7.0.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (8.6.0)
# Requirement already satisfied: tqdm>=4.62.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/manu/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.0->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/manu/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.0->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/manu/anaconda3/lib/python3.12/site-packages (from pandas>=1.3.0->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 6)) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 6)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from scikit-learn>=1.0.0->-r requirements.txt (line 6)) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/manu/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 9)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/manu/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 9)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 9)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/manu/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 9)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 9)) (24.1)
# Requirement already satisfied: pillow>=8 in /home/manu/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 9)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/manu/anaconda3/lib/python3.12/site-packages (from matplotlib>=3.4.0->-r requirements.txt (line 9)) (3.1.2)
# Requirement already satisfied: decorator in /home/manu/anaconda3/lib/python3.12/site-packages (from ipython>=7.0.0->-r requirements.txt (line 12)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/manu/anaconda3/lib/python3.12/site-packages (from ipython>=7.0.0->-r requirements.txt (line 12)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /home/manu/anaconda3/lib/python3.12/site-packages (from ipython>=7.0.0->-r requirements.txt (line 12)) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /home/manu/anaconda3/lib/python3.12/site-packages (from ipython>=7.0.0->-r requirements.txt (line 12)) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from ipython>=7.0.0->-r requirements.txt (line 12)) (2.15.1)
# Requirement already satisfied: stack-data in /home/manu/anaconda3/lib/python3.12/site-packages (from ipython>=7.0.0->-r requirements.txt (line 12)) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from ipython>=7.0.0->-r requirements.txt (line 12)) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /home/manu/anaconda3/lib/python3.12/site-packages (from ipython>=7.0.0->-r requirements.txt (line 12)) (4.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/manu/anaconda3/lib/python3.12/site-packages (from jupyter_client>=7.0.0->-r requirements.txt (line 13)) (5.7.2)
# Requirement already satisfied: pyzmq>=23.0 in /home/manu/anaconda3/lib/python3.12/site-packages (from jupyter_client>=7.0.0->-r requirements.txt (line 13)) (25.1.2)
# Requirement already satisfied: tornado>=6.2 in /home/manu/anaconda3/lib/python3.12/site-packages (from jupyter_client>=7.0.0->-r requirements.txt (line 13)) (6.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/manu/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.0.0->-r requirements.txt (line 12)) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/manu/anaconda3/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter_client>=7.0.0->-r requirements.txt (line 13)) (3.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/manu/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.0.0->-r requirements.txt (line 12)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/manu/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.0.0->-r requirements.txt (line 12)) (0.2.5)
# Requirement already satisfied: six>=1.5 in /home/manu/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: executing in /home/manu/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.0.0->-r requirements.txt (line 12)) (0.8.3)
# Requirement already satisfied: asttokens in /home/manu/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.0.0->-r requirements.txt (line 12)) (2.0.5)
# Requirement already satisfied: pure-eval in /home/manu/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.0.0->-r requirements.txt (line 12)) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Fase 0 — Pulizia del dataset (Excel → CSV clean)
#
# Questa fase carica `data/dataset_raw.xlsx` (tre fogli: ASD, GDD, Controlli/Controls) e produce un dataset pulito:
#
# - unisce i fogli e crea la colonna target `class`;
# - rimuove le 5 feature indicate nell’assignment;
# - filtra i pazienti con `Età equivalente < 12`;
# - codifica `Sesso` in forma numerica;
# - gestisce i duplicati di colonne (es. `B10` ripetuta) rinominandoli in modo univoco (`B10_y1`, `B10_y2`, …);
# - esporta **un solo file**: `data/phase0_clean.csv`.

# %%
from pathlib import Path
from src.phase0_clean import Phase0Config, run_phase0

cfg = Phase0Config(
    data_dir=Path("data"),
    input_xlsx="dataset_raw.xlsx",
    output_clean_csv="phase0_clean.csv",
    missing_strategy="drop_rows",  # oppure "impute_median"
)

out = run_phase0(cfg, trace=True)
print("Phase0 output:", out)
# Out:
# [TRACCIA] Trail 'phase0_clean' starting
# [TRACCIA] -> LoadXLSX
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 11
#       2 from src.phase0_clean import Phase0Config, run_phase0
#       4 cfg = Phase0Config(
#       5     data_dir=Path("data"),
#       6     input_xlsx="dataset_raw.xlsx",
#       7     output_clean_csv="phase0_clean.csv",
#       8     missing_strategy="drop_rows",  # oppure "impute_median"
#       9 )
# ---> 11 out = run_phase0(cfg, trace=True)
#      12 print("Phase0 output:", out)
#
# File ~/Documents/Sylloge-by-Manu/IDM_2526/classwork2/src/phase0_clean.py:321, in run_phase0(cfg, trace)
#     319 cfg = cfg or Phase0Config()
#     320 fp = Phase0Footprint(cfg=cfg)
# --> 321 fp = build_phase0_trail(cfg, trace=trace).run(fp)
#     322 assert fp.output_path is not None
#     323 return fp.output_path
#
# File ~/anaconda3/lib/python3.12/site-packages/traccia/core/trail.py:205, in Trail.run(self, footprint)
#     203         if self.trace_enabled:
#     204             print(f"[TRACCIA] -> {s.name}")
# --> 205         footprint = s(footprint)
#     206 finally:
#     207     meta.mark_finished()
#
# File ~/anaconda3/lib/python3.12/site-packages/traccia/core/step.py:25, in Step.__call__(self, footprint)
#      22 except Exception:
#      23     # Metadata is best-effort; never break the step execution.
#      24     pass
# ---> 25 return self.fn(footprint)
#
# File ~/Documents/Sylloge-by-Manu/IDM_2526/classwork2/src/phase0_clean.py:146, in load_xlsx(fp)
#     144 xlsx_path = cfg.data_dir / cfg.input_xlsx
#     145 if not xlsx_path.exists():
# --> 146     raise FileNotFoundError(f"XLSX non trovato: {xlsx_path}")
#     148 # fogli del tuo file
#     149 sheet_map = {
#     150     "ASD": "ASD",
#     151     "GDD": "GDD",
#     152     "Controlli": "Controls",
#     153 }
#
# FileNotFoundError: XLSX non trovato: data/dataset_raw.xlsx

# %% [markdown]
# ## Fase 1 — PCA a 2 componenti e scatter plot
#
# In questa fase carichiamo il dataset pulito e:
#
# - separiamo feature `X` e target `y`;
# - (opzionale ma consigliato) applichiamo **StandardScaler** prima della PCA;
# - riduciamo a 2 dimensioni con **PCA(n_components=2)**;
# - generiamo lo **scatter plot 2D** colorato per classe e salviamo l’immagine in `reports/phase1_pca2d.png`.

# %%
from pathlib import Path
from src.phase1_pca2d import Phase1Config, run_phase1

cfg = Phase1Config(
    data_dir=Path("data"),
    reports_dir=Path("reports"),
    input_clean_csv="phase0_clean.csv",
    output_png="phase1_pca2d.png",
    scale_before_pca=True,
)

out = run_phase1(cfg, trace=True)
print("Phase1 output:", out)
# Out:
# [TRACCIA] Trail 'phase1_pca2d' starting
# [TRACCIA] -> LoadClean
# [TRACCIA] -> BuildXY
# [TRACCIA] -> ComputePCA2D
# [TRACCIA] -> PlotAndSavePNG
# [TRACCIA] Trail 'phase1_pca2d' finished (handlers=['LoadClean', 'BuildXY', 'ComputePCA2D', 'PlotAndSavePNG'])
# Phase1 output: reports/phase1_pca2d.png

# %% [markdown]
# ## Fase 2 — Train/Test split + GridSearchCV (5-fold)
#
# Questa fase implementa il Task principale di classificazione:
#
# - split stratificato train/test;
# - per ciascun modello (Decision Tree, Random Forest, SVC, K-NN) eseguiamo una **GridSearchCV con 5-fold cross validation** per selezionare iperparametri che riducano l’overfitting;
# - valutiamo il modello migliore su test con metriche (accuracy e F1-macro);
# - esportiamo **un solo file**: `reports/phase2_gridsearch.json` con best params, score CV e metriche su test.

# %%
from pathlib import Path
from src.phase2_gridsearch import Phase2Config, run_phase2

cfg = Phase2Config(
    data_dir=Path("data"),
    reports_dir=Path("reports"),
    scoring="f1_macro",
)

out = run_phase2(cfg, trace=True)
print("Phase2 output:", out)
# Out:
# [TRACCIA] Trail 'phase2_gridsearch' starting
# [TRACCIA] -> LoadClean
# [TRACCIA] -> BuildXY
# [TRACCIA] -> SplitTrainTest
# [TRACCIA] -> GridSearchAllModels
# [TRACCIA] -> ExportJSON
# [TRACCIA] Trail 'phase2_gridsearch' finished (handlers=['LoadClean', 'BuildXY', 'SplitTrainTest', 'GridSearchAllModels', 'ExportJSON'])
# Phase2 output: reports/phase2_gridsearch.json

# %% [markdown]
# ## Report risultati Fase 2 — tabella comparativa
#
# Qui leggiamo `reports/phase2_gridsearch.json` e costruiamo una tabella comparativa con:
#
# - miglior score in cross-validation (F1 macro),
# - accuracy e F1 macro sul test set,
# - iperparametri migliori trovati per ciascun modello.

# %%
import json
import pandas as pd
from pathlib import Path

json_path = Path("reports/phase2_gridsearch.json")

with json_path.open("r", encoding="utf-8") as f:
    data = json.load(f)

results = data["results"]

rows = []
for model_name, res in results.items():
    rows.append({
        "Model": model_name,
        "CV Best Score (f1_macro)": round(res["cv_best_score"], 4),
        "Test Accuracy": round(res["accuracy_test"], 4),
        "Test F1 Macro": round(res["f1_macro_test"], 4),
        "Best Params": res["best_params"],
    })

df_results = pd.DataFrame(rows).sort_values("Test F1 Macro", ascending=False)
df_results
# Out:
#           Model  CV Best Score (f1_macro)  Test Accuracy  Test F1 Macro  \
# 0  DecisionTree                    0.6062          0.725         0.7230
# 2           SVC                    0.6972          0.650         0.6518
# 3           KNN                    0.6024          0.625         0.6257
# 1  RandomForest                    0.7230          0.625         0.6186
#
#                                          Best Params
# 0          {'max_depth': 5, 'min_samples_split': 10}
# 2           {'svc__C': 0.1, 'svc__kernel': 'linear'}
# 3  {'knn__n_neighbors': 5, 'knn__weights': 'dista...
# 1             {'max_depth': 10, 'n_estimators': 300}

# %% [markdown]
# ## Report Fase 2 — confusion matrix di un modello
#
# In questa cella ispezioniamo la **confusion matrix** di uno specifico modello (impostato in `model_name`).
# La matrice permette di capire dove avvengono gli errori di classificazione tra ASD, GDD e Controls.

# %%
model_name = "DecisionTree"

cm = results[model_name]["confusion_matrix"]
print("Confusion Matrix:")
print(pd.DataFrame(cm))
# Out:
# Confusion Matrix:
#     0  1   2
# 0  11  1   3
# 1   0  7   4
# 2   1  2  11

# %% [markdown]
# ## Fase 3 — Ensemble learning: Bagging e Boosting
#
# In questa fase applichiamo i concetti di ensemble richiesti:
#
# - **Bagging**: più Decision Tree addestrati su bootstrap / sotto-campionamenti per ridurre la varianza;
# - **Boosting (AdaBoost)**: sequenza di weak learners (stump) che si concentrano progressivamente sugli errori.
#
# Valutiamo entrambi su test set e salviamo **un solo file**: `reports/phase3_ensembles.json`.

# %%
from pathlib import Path
import json
import pandas as pd

from src.phase3_ensembles import Phase3Config, run_phase3

cfg = Phase3Config(
    data_dir=Path("data"),
    reports_dir=Path("reports"),
    input_clean_csv="phase0_clean.csv",
    output_json="phase3_ensembles.json",
    test_size=0.2,
    random_state=42,
)

out = run_phase3(cfg, trace=True)
print("Phase3 output:", out)

with open(out, "r", encoding="utf-8") as f:
    data = json.load(f)

rows = []
for k, r in data["results"].items():
    rows.append({
        "Ensemble": r["model_name"],
        "Test Accuracy": round(r["accuracy_test"], 4),
        "Test F1 Macro": round(r["f1_macro_test"], 4),
        "Params": r["params"],
    })

pd.DataFrame(rows).sort_values("Test F1 Macro", ascending=False)
# Out:
# [TRACCIA] Trail 'phase3_ensembles' starting
# [TRACCIA] -> LoadClean
# [TRACCIA] -> BuildXY
# [TRACCIA] -> SplitTrainTest
# [TRACCIA] -> TrainBagging
# [TRACCIA] -> TrainBoosting
# [TRACCIA] -> ExportJSON
# [TRACCIA] Trail 'phase3_ensembles' finished (handlers=['LoadClean', 'BuildXY', 'SplitTrainTest', 'TrainBagging', 'TrainBoosting', 'ExportJSON'])
# Phase3 output: reports/phase3_ensembles.json
#                  Ensemble  Test Accuracy  Test F1 Macro  \
# 0   Bagging(DecisionTree)          0.650         0.6424
# 1  AdaBoost(DecisionTree)          0.575         0.5637
#
#                                               Params
# 0  {'n_estimators': 300, 'max_samples': 0.8, 'max...
# 1  {'n_estimators': 300, 'learning_rate': 0.5, 'b...

# %% [markdown]
# ## Report risultati Fase 3 — confronto + dettagli per classe
#
# Qui produciamo un report leggibile per gli ensemble:
#
# - tabella comparativa (accuracy e F1 macro sul test);
# - confusion matrix per ciascun ensemble;
# - classification report con precision/recall/F1 per classe.

# %%
import json
import pandas as pd
from pathlib import Path

# ---- Carica JSON ----
json_path = Path("reports/phase3_ensembles.json")

with json_path.open("r", encoding="utf-8") as f:
    data = json.load(f)

results = data["results"]

# ---- Tabella comparativa principale ----
rows = []
for name, res in results.items():
    rows.append({
        "Model": res["model_name"],
        "Accuracy (test)": round(res["accuracy_test"], 4),
        "F1 Macro (test)": round(res["f1_macro_test"], 4),
    })

df_summary = pd.DataFrame(rows).sort_values("F1 Macro (test)", ascending=False)

print("=== Phase 3 - Ensemble Comparison ===")
display(df_summary)

# ---- Miglior modello ----
best_model = df_summary.iloc[0]["Model"]
print(f"\nBest Ensemble (by F1 Macro): {best_model}\n")

# ---- Confusion Matrix + Metriche dettagliate ----
for name, res in results.items():
    print("="*60)
    print(f"Model: {res['model_name']}")
    print("-"*60)

    # Confusion Matrix
    labels = res["labels"]
    cm = pd.DataFrame(res["confusion_matrix"], index=labels, columns=labels)
    print("Confusion Matrix:")
    display(cm)

    # Metriche per classe
    report_df = pd.DataFrame(res["classification_report"]).T
    print("Classification Report:")
    display(report_df.round(4))

    print("\n")
# Out:
# === Phase 3 - Ensemble Comparison ===
#                     Model  Accuracy (test)  F1 Macro (test)
# 0   Bagging(DecisionTree)            0.650           0.6424
# 1  AdaBoost(DecisionTree)            0.575           0.5637
# Best Ensemble (by F1 Macro): Bagging(DecisionTree)
#
# ============================================================
# Model: Bagging(DecisionTree)
# ------------------------------------------------------------
# Confusion Matrix:
#           ASD  Controls  GDD
# ASD        12         1    2
# Controls    0         7    4
# GDD         3         4    7
# Classification Report:
#               precision  recall  f1-score  support
# ASD              0.8000  0.8000    0.8000    15.00
# Controls         0.5833  0.6364    0.6087    11.00
# GDD              0.5385  0.5000    0.5185    14.00
# accuracy         0.6500  0.6500    0.6500     0.65
# macro avg        0.6406  0.6455    0.6424    40.00
# weighted avg     0.6489  0.6500    0.6489    40.00
# ============================================================
# Model: AdaBoost(DecisionTree)
# ------------------------------------------------------------
# Confusion Matrix:
#           ASD  Controls  GDD
# ASD        10         1    4
# Controls    0         4    7
# GDD         2         3    9
# Classification Report:
#               precision  recall  f1-score  support
# ASD              0.8333  0.6667    0.7407   15.000
# Controls         0.5000  0.3636    0.4211   11.000
# GDD              0.4500  0.6429    0.5294   14.000
# accuracy         0.5750  0.5750    0.5750    0.575
# macro avg        0.5944  0.5577    0.5637   40.000
# weighted avg     0.6075  0.5750    0.5789   40.000
